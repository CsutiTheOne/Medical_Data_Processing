# %%
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
from torch import tensor
import helpers as h
import random
import os

import transformtest as tt

# %%
path = "Data/medical data/skin_lesions_classification/train"
lesions = os.listdir(path)

def getRandomImage():
    l = random.choice(lesions)
    img = random.choice(os.listdir(f"{path}/{l}"))
    return f"{path}/{l}/{img}"

# %%
imgPath = getRandomImage()
tt.plotImage(imgPath)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.78431356..1.4002206].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2659212..1.3832442].
